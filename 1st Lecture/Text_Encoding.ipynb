# %%
Encoding = "All, ok"
print(Encoding)
# Out:
# All, ok

# %%
# Let me import the Pandas

# %%
import pandas as pd

# %% [markdown]
# # Data
#
# - This below is my data

# %%
data=pd.DataFrame({"text":["people watch cricket","cricket watch cricket","people give comment","cricket give comment"],"output":[1,1,0,0]})

# %%
data
# Out:
#                     text  output
# 0   people watch cricket       1
# 1  cricket watch cricket       1
# 2    people give comment       0
# 3   cricket give comment       0

# %% [markdown]
# # scikit-learn
#
# - Let me install it and keep inside the - Requirement.txt section

# %%
pip install scikit-learn
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.1 MB 229.9 kB/s eta 0:00:47
#    - -------------------------------------- 0.5/11.1 MB 229.9 kB/s eta 0:00:47
#    - -------------------------------------- 0.5/11.1 MB 229.9 kB/s eta 0:00:47
#    - -------------------------------------- 0.5/11.1 MB 229.9 kB/s eta 0:00:47
#    - -------------------------------------- 0.5/11.1 MB 229.9 kB/s eta 0:00:47
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# [ "CountVectorizer" ]
- Now here I am going to creat a object vector for this - [ "CountVectorizer" ]
- If we want to know more in detail we can chech this official Document - ow here I am going to creat a object vector for this - [ "CountVectorizer" ]
